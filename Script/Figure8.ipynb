# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# Read the CSV file into a DataFrame
df = pd.read_csv('Data_TC/Proc/Ensemble_member.csv')

fig, axes = plt.subplots(2, 3, figsize=(10, 6), sharex=False) 

# Plot WP
lines = []  

lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='k',linewidth=1.5,label='lag0')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='orangered',linewidth=1.5,label='lag1')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='dodgerblue',linewidth=1.5,label='lag2')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='darkgoldenrod',linewidth=1.5,label='lag3')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='seagreen',linewidth=1.5,label='lag4')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='yellowgreen',linewidth=1.5,label='lag5')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='navy',linewidth=1.5,label='lag6')[0]) 
lines.append(axes[0, 0].plot(df['Ens_Size'], df['forlegend'], linestyle='-', color='Purple',linewidth=1.5,label='lag6')[0]) 

lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_1'], linestyle='-', color='k', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_2'], linestyle='-', color='orangered', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_3'], linestyle='-', color='dodgerblue', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_4'], linestyle='-', color='darkgoldenrod', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_5'], linestyle='-', color='seagreen', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_6'], linestyle='-', color='yellowgreen', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_7'], linestyle='-', color='navy', linewidth=1)[0])
lines.append(axes[0, 0].plot(df['Ens_Size'], df['WP_week_8'], linestyle='-', color='Purple', linewidth=1)[0])


axes[0, 0].set_title('NWP', fontsize=12)
axes[0, 0].set_ylim(-1, 0.3)
axes[0, 0].xaxis.set_major_locator(plt.MultipleLocator(1))
axes[0, 0].xaxis.set_minor_locator(plt.MultipleLocator(1))
axes[0, 0].yaxis.set_minor_locator(AutoMinorLocator())
axes[0, 0].set_xticks(range(0, 17))
axes[0, 0].tick_params(axis='both', labelsize=10)

# Plot EP
axes[0, 1].plot(df['Ens_Size'], df['EP_week_1'], linestyle='-', color='k', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_2'], linestyle='-', color='orangered', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_3'], linestyle='-', color='dodgerblue', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_4'], linestyle='-', color='darkgoldenrod', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_5'], linestyle='-', color='seagreen', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_6'], linestyle='-', color='yellowgreen', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_7'], linestyle='-', color='navy', linewidth=1)
axes[0, 1].plot(df['Ens_Size'], df['EP_week_8'], linestyle='-', color='Purple', linewidth=1)


axes[0, 1].set_title('EP', fontsize=12)
axes[0, 1].set_ylim(-1, 0.3)
axes[0, 1].xaxis.set_major_locator(plt.MultipleLocator(1))
axes[0, 1].xaxis.set_minor_locator(plt.MultipleLocator(1))
axes[0, 1].yaxis.set_minor_locator(AutoMinorLocator())
axes[0, 1].set_xticks(range(0, 17))
axes[0, 1].tick_params(axis='both', labelsize=10)

# Plot SH
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_1'], linestyle='-', color='k', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_2'], linestyle='-', color='orangered', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_3'], linestyle='-', color='dodgerblue', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_4'], linestyle='-', color='darkgoldenrod', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_5'], linestyle='-', color='seagreen', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_6'], linestyle='-', color='yellowgreen', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_7'], linestyle='-', color='navy', linewidth=1)
axes[1, 0].plot(df['Ens_Size'], df['NIO_week_8'], linestyle='-', color='Purple', linewidth=1)

axes[1, 0].set_title('NI', fontsize=12)
axes[1, 0].set_ylim(-1, 0.3)
axes[1, 0].xaxis.set_major_locator(plt.MultipleLocator(1))
axes[1, 0].xaxis.set_minor_locator(plt.MultipleLocator(1))
axes[1, 0].yaxis.set_minor_locator(AutoMinorLocator())
axes[1, 0].set_xticks(range(0, 17))
axes[1, 0].tick_params(axis='both', labelsize=10)

# Plot NA
axes[0, 2].plot(df['Ens_Size'], df['NA_week_1'], linestyle='-', color='k', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_2'], linestyle='-', color='orangered', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_3'], linestyle='-', color='dodgerblue', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_4'], linestyle='-', color='darkgoldenrod', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_5'], linestyle='-', color='seagreen', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_6'], linestyle='-', color='yellowgreen', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_7'], linestyle='-', color='navy', linewidth=1)
axes[0, 2].plot(df['Ens_Size'], df['NA_week_8'], linestyle='-', color='Purple', linewidth=1)


axes[0, 2].set_title('NA', fontsize=12)
axes[0, 2].set_ylim(-1, 0.3)
axes[0, 2].xaxis.set_major_locator(plt.MultipleLocator(1))
axes[0, 2].xaxis.set_minor_locator(plt.MultipleLocator(1))
axes[0, 2].yaxis.set_minor_locator(AutoMinorLocator())
axes[0, 2].set_xticks(range(0, 17))
axes[1, 1].tick_params(axis='both', labelsize=10)


new_subplot = axes[1, 1]

# Plot EP
axes[1, 1].plot(df['Ens_Size'], df['SH_week_1'], linestyle='-', color='k', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_2'], linestyle='-', color='orangered', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_3'], linestyle='-', color='dodgerblue', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_4'], linestyle='-', color='darkgoldenrod', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_5'], linestyle='-', color='seagreen', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_6'], linestyle='-', color='yellowgreen', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_7'], linestyle='-', color='navy', linewidth=1)
axes[1, 1].plot(df['Ens_Size'], df['SH_week_8'], linestyle='-', color='Purple', linewidth=1)

axes[1, 1].set_title('SH', fontsize=14)
axes[1, 1].set_ylim(-1, 0.3)
axes[0, 2].xaxis.set_major_locator(plt.MultipleLocator(1))
axes[0, 2].xaxis.set_minor_locator(plt.MultipleLocator(1))
axes[0, 2].yaxis.set_minor_locator(AutoMinorLocator())
axes[0, 2].set_xticks(range(0, 17))
axes[1, 1].tick_params(axis='y', labelsize=10)
axes[1, 1].tick_params(axis='x', labelsize=10)

# Remove the empty subplot
fig.delaxes(axes[1, 2])

for ax in axes.flat:
    for _, spine in ax.spines.items():
        spine.set_linewidth(1)

axes[0, 0].axhline(0, color='grey', alpha=1, linewidth=0.6, linestyle='-')
axes[0, 1].axhline(0, color='grey', alpha=1, linewidth=0.6, linestyle='-')
axes[1, 1].axhline(0, color='grey', alpha=1, linewidth=0.6, linestyle='-')
axes[1, 0].axhline(0, color='grey', alpha=1, linewidth=0.6, linestyle='-')
axes[0, 2].axhline(0, color='grey', alpha=1, linewidth=0.6, linestyle='-')

axes[0, 0].text(0.2, 0.19, '(a)', fontsize=12,)
axes[0, 1].text(0.2, 0.19, '(b)', fontsize=12,)
axes[0, 2].text(0.2, 0.19, '(c)', fontsize=12,)
axes[1, 0].text(0.2, 0.19, '(d)', fontsize=12,)
axes[1, 1].text(0.2, 0.19, '(e)', fontsize=12,)

axes[0, 0].set_xticks(range(0, 17, 2))
axes[0, 1].set_xticks(range(0, 17, 2))
axes[1, 0].set_xticks(range(0, 17, 2))
axes[1, 1].set_xticks(range(0, 17, 2))
axes[0, 2].set_xticks(range(0, 17, 2))


fig.text(0.36, 0.0, 'Ensemble size', ha='center', va='center', rotation='horizontal', fontsize=12)
fig.text(0.84, 0.5, 'Ensemble size', ha='center', va='center', rotation='horizontal', fontsize=12)

legend_axes = fig.add_subplot(2, 3, 6)  
legend_axes.axis('off') 

legend_axes.legend(lines, ['week1', 'week2','week3','week4','week5','week6','week7','week8'], loc='upper left', ncols=2, facecolor='white',fontsize=12)

plt.tight_layout()

#plt.savefig('Figures/Figure8_Ensembles_member.png', dpi=400, bbox_inches='tight')
plt.show()
